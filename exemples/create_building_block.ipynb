# %%
import sys

sys.path.append('C:\\Users\\lipel\\OneDrive\\Documentos\\GitHub\\pyCOFBuilder\\src')

import pycofbuilder as pcb

# %%
pcb.IO_Tools.generate_mol_dict(
    path='C:\\Users\\lipel\\OneDrive\\Documentos\\GitHub\\pyCOFBuilder\\src\\pycofbuilder\\data\\core\\S4', 
    file_name='PHPR.gjf',
    name='5,10,15,20-tetraphenylporphyrin',
    code='PHPR',
    smiles="[Q]C(C([R2])=C1[R4])=C([R1])C([R3])=C1/C(C2=C([R5])C([R6])=C(/C(C3=C([R3])C([R1])=C([Q])C([R2])=C3[R4])=C4C([R5])=C([R6])C5=N/4)N2)=C6N=C(/C(C7=C([R3])C([R1])=C([Q])C([R2])=C7[R4])=C(C([R6])=C/8[R5])\\NC8=C5\C9=C([R3])C([R1])=C([Q])C([R2])=C9[R4])C([R5])=C/6[R6]")
# Out:
# {'name': '5,10,15,20-tetraphenylporphyrin', 'smiles': '[Q]C(C([R2])=C1[R4])=C([R1])C([R3])=C1/C(C2=C([R5])C([R6])=C(/C(C3=C([R3])C([R1])=C([Q])C([R2])=C3[R4])=C4C([R5])=C([R6])C5=N/4)N2)=C6N=C(/C(C7=C([R3])C([R1])=C([Q])C([R2])=C7[R4])=C(C([R6])=C/8[R5])\\NC8=C5\\C9=C([R3])C([R1])=C([Q])C([R2])=C9[R4])C([R5])=C/6[R6]', 'code': 'PHPR', 'xsmiles': '[*]C(C([*])=C1[*])=C([*])C([*])=C1/C(C2=C([*])C([*])=C(/C(C3=C([*])C([*])=C([*])C([*])=C3[*])=C4C([*])=C([*])C5=N/4)N2)=C6N=C(/C(C7=C([*])C([*])=C([*])C([*])=C7[*])=C(C([*])=C/8[*])\\NC8=C5\\C9=C([*])C([*])=C([*])C([*])=C9[*])C([*])=C/6[*]', 'xsmiles_label': '|$Q;;;R2;;R4;;R1;;R3;;;;;R5;;R6;;;;;R3;;R1;;Q;;R2;;R4;;;R5;;R6;;;;;;;;;;R3;;R1;;Q;;R2;;R4;;;R6;;R5;;;;;;R3;;R1;;Q;;R2;;R4;;R5;;R6$|', 'formula': 'R64C44R54N4R14R24R34R44Q4', 'atoms': {'elements': {'elementType': ['C', 'C', 'C', 'C', 'N', 'C', 'C', 'C', 'C', 'N', 'C', 'C', 'C', 'C', 'N', 'C', 'C', 'C', 'C', 'C', 'C', 'N', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', '
# ...

# %%
pcb.IO_Tools.generate_mol_dict(
    path='C:\\Users\\lipel\\OneDrive\\Documentos\\GitHub\\pyCOFBuilder\\src\\pycofbuilder\\data\\core\\S4', 
    file_name='PTCA.gjf',
    name='phthalocyanine',
    code='PTCA',
    smiles="[Q]C1=C([R1])C2=C(/N=C3C4=C(C([R1])=C([Q])C([R2])=C4[R3])C5=N/3)NC(/N=C6N=C(/N=C(C7=C/8C([R3])=C([R2])C([Q])=C7[R1])\\NC8=N/5)C9=C\6C([R1])=C([Q])C([R2])=C9[R3])=C2C([R3])=C1[R2]")
# Out:
# {'name': 'phthalocyanine', 'smiles': '[Q]C1=C([R1])C2=C(/N=C3C4=C(C([R1])=C([Q])C([R2])=C4[R3])C5=N/3)NC(/N=C6N=C(/N=C(C7=C/8C([R3])=C([R2])C([Q])=C7[R1])\\NC8=N/5)C9=C\x06C([R1])=C([Q])C([R2])=C9[R3])=C2C([R3])=C1[R2]', 'code': 'PTCA', 'xsmiles': '[*]C1=C([*])C2=C(/N=C3C4=C(C([*])=C([*])C([*])=C4[*])C5=N/3)NC(/N=C6N=C(/N=C(C7=C/8C([*])=C([*])C([*])=C7[*])\\NC8=N/5)C9=C\x06C([*])=C([*])C([*])=C9[*])=C2C([*])=C1[*]', 'xsmiles_label': '|$Q;;;R1;;;;;;;;R1;;Q;;R2;;R3;;;;;;;;;;;;;;R3;;R2;;Q;;R1;;;;;;;R1;;Q;;R2;;R3;;;R3;;R2$|', 'formula': 'C32N8R14R24R34Q4', 'atoms': {'elements': {'elementType': ['C', 'C', 'C', 'N', 'C', 'N', 'C', 'C', 'C', 'N', 'C', 'C', 'C', 'N', 'C', 'C', 'N', 'N', 'N', 'N', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'H', 'H', 'Q', 'Q', 'Q', 'Q', 'R1', 'R1', 'R1', 'R1', 'R2', 'R2', 'R2', 'R2', 'R3', 'R3', 'R3', 'R3']}, 'coords': {'3d': [[1.0759548, 2.72148862, 0.0], [0.60957846, 4.17968893, 0.0], [-1.14302574, 2.7
# ...

# %%
pcb.IO_Tools.generate_mol_dict(
    path='C:\\Users\\lipel\\OneDrive\\Documentos\\GitHub\\pyCOFBuilder\\src\\pycofbuilder\\data\\core\\H6', 
    file_name='HECO.gjf',
    name='hexabenzo[bc,ef,hi,kl,no,qr]coronene',
    code='HECO',
    smiles="[Q]C(C([R2])=C12)=C([R1])C3=C1C4=C(C5=C6C([R1])=C([Q])C([R2])=C53)C(C7=C8C([R1])=C([Q])C([R2])=C76)=C(C9=C%10C([R1])=C([Q])C([R2])=C98)C%11=C4C%12=C2C([R1])=C([Q])C([R2])=C%12C%13=C%11C%10=C([R2])C([Q])=C%13[R1]")
# Out:
# {'name': 'hexabenzo[bc,ef,hi,kl,no,qr]coronene', 'smiles': '[Q]C(C([R2])=C12)=C([R1])C3=C1C4=C(C5=C6C([R1])=C([Q])C([R2])=C53)C(C7=C8C([R1])=C([Q])C([R2])=C76)=C(C9=C%10C([R1])=C([Q])C([R2])=C98)C%11=C4C%12=C2C([R1])=C([Q])C([R2])=C%12C%13=C%11C%10=C([R2])C([Q])=C%13[R1]', 'code': 'HECO', 'xsmiles': '[*]C(C([*])=C12)=C([*])C3=C1C4=C(C5=C6C([*])=C([*])C([*])=C53)C(C7=C8C([*])=C([*])C([*])=C76)=C(C9=C%10C([*])=C([*])C([*])=C98)C%11=C4C%12=C2C([*])=C([*])C([*])=C%12C%13=C%11C%10=C([*])C([*])=C%13[*]', 'xsmiles_label': '|$Q;;;R2;;;R1;;;;;;;;R1;;Q;;R2;;;;;;R1;;Q;;R2;;;;;;R1;;Q;;R2;;;;;;;R1;;Q;;R2;;;;;;R2;;Q;;R1$|', 'formula': 'Q6R26C42R16', 'atoms': {'elements': {'elementType': ['C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'Q', 'Q', 'Q', 'Q', 'Q', 'Q', 'R1', 'R1', 'R1', 'R1', 'R1', 'R1', 'R2', 'R2', 'R2', 'R2', 'R2', 'R2']}, '
# ...

# %%
pcb.IO_Tools.generate_mol_dict(
    path='C:\\Users\\lipel\\OneDrive\\Documentos\\GitHub\\pyCOFBuilder\\src\\pycofbuilder\\data\\core\\H6', 
    file_name='HPCO.gjf',
    name='2,5,8,11,14,17-hexaphenylhexabenzo[bc,ef,hi,kl,no,qr]coronene',
    code='HPCO',
    smiles="[Q]C(C([R2])=C1[R4])=C([R1])C([R3])=C1C(C([R6])=C23)=C([R5])C4=C2C5=C(C6=C7C([R5])=C(C8=C([R3])C([R1])=C([Q])C([R2])=C8[R4])C([R6])=C64)C(C9=C%10C([R5])=C(C%11=C([R3])C([R1])=C([Q])C([R2])=C%11[R4])C([R6])=C97)=C(C%12=C%13C([R5])=C(C%14=C([R3])C([R1])=C([Q])C([R2])=C%14[R4])C([R6])=C%12%10)C%15=C5C%16=C3C([R5])=C(C%17=C([R3])C([R1])=C([Q])C([R2])=C%17[R4])C([R6])=C%16C%18=C%15C%13=C([R6])C(C%19=C([R3])C([R1])=C([Q])C([R2])=C%19[R4])=C%18[R5]")
# Out:
# {'name': '2,5,8,11,14,17-hexaphenylhexabenzo[bc,ef,hi,kl,no,qr]coronene', 'smiles': '[Q]C(C([R2])=C1[R4])=C([R1])C([R3])=C1C(C([R6])=C23)=C([R5])C4=C2C5=C(C6=C7C([R5])=C(C8=C([R3])C([R1])=C([Q])C([R2])=C8[R4])C([R6])=C64)C(C9=C%10C([R5])=C(C%11=C([R3])C([R1])=C([Q])C([R2])=C%11[R4])C([R6])=C97)=C(C%12=C%13C([R5])=C(C%14=C([R3])C([R1])=C([Q])C([R2])=C%14[R4])C([R6])=C%12%10)C%15=C5C%16=C3C([R5])=C(C%17=C([R3])C([R1])=C([Q])C([R2])=C%17[R4])C([R6])=C%16C%18=C%15C%13=C([R6])C(C%19=C([R3])C([R1])=C([Q])C([R2])=C%19[R4])=C%18[R5]', 'code': 'HPCO', 'xsmiles': '[*]C(C([*])=C1[*])=C([*])C([*])=C1C(C([*])=C23)=C([*])C4=C2C5=C(C6=C7C([*])=C(C8=C([*])C([*])=C([*])C([*])=C8[*])C([*])=C64)C(C9=C%10C([*])=C(C%11=C([*])C([*])=C([*])C([*])=C%11[*])C([*])=C97)=C(C%12=C%13C([*])=C(C%14=C([*])C([*])=C([*])C([*])=C%14[*])C([*])=C%12%10)C%15=C5C%16=C3C([*])=C(C%17=C([*])C([*])=C([*])C([*])=C%17[*])C([*])=C%16C%18=C%15C%13=C([*])C(C%19=C([*])C([*])=C([*])C([*])=C%19[*])=C%18[*]', 'xsmiles_label': '|$Q;;;R
# ...

# %%
A = '[Q]C(C([R2])=C12)=C([R1])C3=C1C4=C(C5=C6C([R1])=C([Q])C([R2])=C53)C(C7=C8C([R1])=C([Q])C([R2])=C76)=C(C9=C%10C([R1])=C([Q])C([R2])=C98)C%11=C4C%12=C2C([R1])=C([Q])C([R2])=C%12C%13=C%11C%10=C([R2])C([Q])=C%13[R1]'

# %%
BB1 = pcb.BuildingBlock(name='H6_HPCO_NH2_H', verbosity=True, save_bb=False)

print(repr(BB1))
print(BB1.smiles)
# Out:
# BuildingBlock(H6, HPCO, NH2, ['H', 'H', 'H', 'H', 'H', 'H'])
# (N)C(C([H])=C1[H])=C([H])C([H])=C1C(C([H])=C23)=C([H])C4=C2C5=C(C6=C7C([H])=C(C8=C([H])C([H])=C((N))C([H])=C8[H])C([H])=C64)C(C9=C%10C([H])=C(C%11=C([H])C([H])=C((N))C([H])=C%11[H])C([H])=C97)=C(C%12=C%13C([H])=C(C%14=C([H])C([H])=C((N))C([H])=C%14[H])C([H])=C%12%10)C%15=C5C%16=C3C([H])=C(C%17=C([H])C([H])=C((N))C([H])=C%17[H])C([H])=C%16C%18=C%15C%13=C([H])C(C%19=C([H])C([H])=C((N))C([H])=C%19[H])=C%18[H]
